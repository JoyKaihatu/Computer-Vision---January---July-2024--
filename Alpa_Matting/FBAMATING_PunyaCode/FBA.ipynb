# %%
import numpy as np
import numpy.linalg
import scipy.sparse
import scipy.sparse.linalg
from PIL import Image
from numba import njit
# import matplotlib.pyplot as plt

def main():
    # configure paths here
    image_path  = "FBAMATING_PunyaGambar/87ZMG.png"
    trimap_path = "FBAMATING_PunyaGambar/trimaps/87ZMG.png"
    alpha_path  = "cat2.png"
    cutout_path = "cat2_cutout.png"

    # load and convert to [0, 1] range
    image  = np.array(Image.open( image_path).convert("RGB"))/255.0
    trimap = np.array(Image.open(trimap_path).convert(  "L"))/255.0

    # make matting laplacian
    i,j,v = closed_form_laplacian(image)
    h,w = trimap.shape
    L = scipy.sparse.csr_matrix((v, (i, j)), shape=(w*h, w*h))

    # build linear system
    A, b = make_system(L, trimap)

    # solve sparse linear system
    print("solving linear system...")
    alpha = scipy.sparse.linalg.spsolve(A, b).reshape(h, w)

    # stack rgb and alpha
    cutout = np.concatenate([image, alpha[:, :, np.newaxis]], axis=2)

    # clip and convert to uint8 for PIL
    cutout = np.clip(cutout*255, 0, 255).astype(np.uint8)
    alpha  = np.clip( alpha*255, 0, 255).astype(np.uint8)

    # save and show
    Image.fromarray(alpha ).save( alpha_path)
    Image.fromarray(cutout).save(cutout_path)
    Image.fromarray(alpha ).show()
    Image.fromarray(cutout).show()


@njit
def closed_form_laplacian(image, epsilon=1e-7, r=1):
    h,w = image.shape[:2]
    window_area = (2*r + 1)**2
    n_vals = (w - 2*r)*(h - 2*r)*window_area**2
    k = 0
    # data for matting laplacian in coordinate form
    i = np.empty(n_vals, dtype=np.int32)
    j = np.empty(n_vals, dtype=np.int32)
    v = np.empty(n_vals, dtype=np.float64)

    # for each pixel of image
    for y in range(r, h - r):
        for x in range(r, w - r):

            # gather neighbors of current pixel in 3x3 window
            n = image[y-r:y+r+1, x-r:x+r+1]
            u = np.zeros(3)
            for p in range(3):
                u[p] = n[:, :, p].mean()
            c = n - u

            # calculate covariance matrix over color channels
            cov = np.zeros((3, 3))
            for p in range(3):
                for q in range(3):
                    cov[p, q] = np.mean(c[:, :, p]*c[:, :, q])

            # calculate inverse covariance of window
            inv_cov = np.linalg.inv(cov + epsilon/window_area * np.eye(3))

            # for each pair ((xi, yi), (xj, yj)) in a 3x3 window
            for dyi in range(2*r + 1):
                for dxi in range(2*r + 1):
                    for dyj in range(2*r + 1):
                        for dxj in range(2*r + 1):
                            i[k] = (x + dxi - r) + (y + dyi - r)*w
                            j[k] = (x + dxj - r) + (y + dyj - r)*w
                            temp = c[dyi, dxi].dot(inv_cov).dot(c[dyj, dxj])
                            v[k] = (1.0 if (i[k] == j[k]) else 0.0) - (1 + temp)/window_area
                            k += 1
        print("generating matting laplacian", y - r + 1, "/", h - 2*r)

    return i, j, v

def make_system(L, trimap, constraint_factor=100.0):
    # split trimap into foreground, background, known and unknown masks
    is_fg = (trimap > 0.9).flatten()
    is_bg = (trimap < 0.1).flatten()
    is_known = is_fg | is_bg
    is_unknown = ~is_known

    # diagonal matrix to constrain known alpha values
    d = is_known.astype(np.float64)
    D = scipy.sparse.diags(d)

    # combine constraints and graph laplacian
    A = constraint_factor*D + L
    # constrained values of known alpha values
    b = constraint_factor*is_fg.astype(np.float64)

    return A, b

if __name__ == "__main__":
    main()
# Out:
# generating matting laplacian 1 / 510
# generating matting laplacian 2 / 510
# generating matting laplacian 3 / 510
# generating matting laplacian 4 / 510
# generating matting laplacian 5 / 510
# generating matting laplacian 6 / 510
# generating matting laplacian 7 / 510
# generating matting laplacian 8 / 510
# generating matting laplacian 9 / 510
# generating matting laplacian 10 / 510
# generating matting laplacian 11 / 510
# generating matting laplacian 12 / 510
# generating matting laplacian 13 / 510
# generating matting laplacian 14 / 510
# generating matting laplacian 15 / 510
# generating matting laplacian 16 / 510
# generating matting laplacian 17 / 510
# generating matting laplacian 18 / 510
# generating matting laplacian 19 / 510
# generating matting laplacian 20 / 510
# generating matting laplacian 21 / 510
# generating matting laplacian 22 / 510
# generating matting laplacian 23 / 510
# generating matting laplacian 24 / 510
# generating matting laplacian 25 / 510
# generating matting laplacian 26 / 510
# generating matting laplacian 27 / 510
# generating matting laplacian 28 / 510
# generating matting laplacian 29 / 510
# generating matting laplacian 30 / 510
# generating matting laplacian 31 / 510
# generating matting laplacian 32 / 510
# generating matting laplacian 33 / 510
# generating matting laplacian 34 / 510
# generating matting laplacian 35 / 510
# generating matting laplacian 36 / 510
# generating matting laplacian 37 / 510
# generating matting laplacian 38 / 510
# generating matting laplacian 39 / 510
# generating matting laplacian 40 / 510
# generating matting laplacian 41 / 510
# generating matting laplacian 42 / 510
# generating matting laplacian 43 / 510
# generating matting laplacian 44 / 510
# generating matting laplacian 45 / 510
# generating matting laplacian 46 / 510
# generating matting laplacian 47 / 510
# generating matting laplacian 48 / 510
# generating matting laplacian 49 / 510
# generating matting laplacian 50 / 510
# generating matting laplacian 51 / 510
# generating matting laplacian 52 / 510
# generating matting laplacian 53 / 510
# generating matting laplacian 54 / 510
# generating matting laplacian 55 / 510
# generating matting laplacian 56 / 510
# generating matting laplacian 57 / 510
# generating matting laplacian 58 / 510
# generating matting laplacian 59 / 510
# generating matting laplacian 60 / 510
# generating matting laplacian 61 / 510
# generating matting laplacian 62 / 510
# generating matting laplacian 63 / 510
# generating matting laplacian 64 / 510
# generating matting laplacian 65 / 510
# generating matting laplacian 66 / 510
# generating matting laplacian 67 / 510
# generating matting laplacian 68 / 510
# generating matting laplacian 69 / 510
# generating matting laplacian 70 / 510
# generating matting laplacian 71 / 510
# generating matting laplacian 72 / 510
# generating matting laplacian 73 / 510
# generating matting laplacian 74 / 510
# generating matting laplacian 75 / 510
# generating matting laplacian 76 / 510
# generating matting laplacian 77 / 510
# generating matting laplacian 78 / 510
# generating matting laplacian 79 / 510
# generating matting laplacian 80 / 510
# generating matting laplacian 81 / 510
# generating matting laplacian 82 / 510
# generating matting laplacian 83 / 510
# generating matting laplacian 84 / 510
# generating matting laplacian 85 / 510
# generating matting laplacian 86 / 510
# generating matting laplacian 87 / 510
# generating matting laplacian 88 / 510
# generating matting laplacian 89 / 510
# generating matting laplacian 90 / 510
# generating matting laplacian 91 / 510
# generating matting laplacian 92 / 510
# generating matting laplacian 93 / 510
# generating matting laplacian 94 / 510
# generating matting laplacian 95 / 510
# generating matting laplacian 96 / 510
# generating matting laplacian 97 / 510
# generating matting laplacian 98 / 510
# generating matting laplacian 99 / 510
# generating matting laplacian 100 / 510
# generating matting laplacian 101 / 510
# generating matting laplacian 102 / 510
# generating matting laplacian 103 / 510
# generating matting laplacian 104 / 510
# generating matting laplacian 105 / 510
# generating matting laplacian 106 / 510
# generating matting laplacian 107 / 510
# generating matting laplacian 108 / 510
# generating matting laplacian 109 / 510
# generating matting laplacian 110 / 510
# generating matting laplacian 111 / 510
# generating matting laplacian 112 / 510
# generating matting laplacian 113 / 510
# generating matting laplacian 114 / 510
# generating matting laplacian 115 / 510
# generating matting laplacian 116 / 510
# generating matting laplacian 117 / 510
# generating matting laplacian 118 / 510
# generating matting laplacian 119 / 510
# generating matting laplacian 120 / 510
# generating matting laplacian 121 / 510
# generating matting laplacian 122 / 510
# generating matting laplacian 123 / 510
# generating matting laplacian 124 / 510
# generating matting laplacian 125 / 510
# generating matting laplacian 126 / 510
# generating matting laplacian 127 / 510
# generating matting laplacian 128 / 510
# generating matting laplacian 129 / 510
# generating matting laplacian 130 / 510
# generating matting laplacian 131 / 510
# generating matting laplacian 132 / 510
# generating matting laplacian 133 / 510
# generating matting laplacian 134 / 510
# generating matting laplacian 135 / 510
# generating matting laplacian 136 / 510
# generating matting laplacian 137 / 510
# generating matting laplacian 138 / 510
# generating matting laplacian 139 / 510
# generating matting laplacian 140 / 510
# generating matting laplacian 141 / 510
# generating matting laplacian 142 / 510
# generating matting laplacian 143 / 510
# generating matting laplacian 144 / 510
# generating matting laplacian 145 / 510
# generating matting laplacian 146 / 510
# generating matting laplacian 147 / 510
# generating matting laplacian 148 / 510
# generating matting laplacian 149 / 510
# generating matting laplacian 150 / 510
# generating matting laplacian 151 / 510
# generating matting laplacian 152 / 510
# generating matting laplacian 153 / 510
# generating matting laplacian 154 / 510
# generating matting laplacian 155 / 510
# generating matting laplacian 156 / 510
# generating matting laplacian 157 / 510
# generating matting laplacian 158 / 510
# generating matting laplacian 159 / 510
# generating matting laplacian 160 / 510
# generating matting laplacian 161 / 510
# generating matting laplacian 162 / 510
# generating matting laplacian 163 / 510
# generating matting laplacian 164 / 510
# generating matting laplacian 165 / 510
# generating matting laplacian 166 / 510
# generating matting laplacian 167 / 510
# generating matting laplacian 168 / 510
# generating matting laplacian 169 / 510
# generating matting laplacian 170 / 510
# generating matting laplacian 171 / 510
# generating matting laplacian 172 / 510
# generating matting laplacian 173 / 510
# generating matting laplacian 174 / 510
# generating matting laplacian 175 / 510
# generating matting laplacian 176 / 510
# generating matting laplacian 177 / 510
# generating matting laplacian 178 / 510
# generating matting laplacian 179 / 510
# generating matting laplacian 180 / 510
# generating matting laplacian 181 / 510
# generating matting laplacian 182 / 510
# generating matting laplacian 183 / 510
# generating matting laplacian 184 / 510
# generating matting laplacian 185 / 510
# generating matting laplacian 186 / 510
# generating matting laplacian 187 / 510
# generating matting laplacian 188 / 510
# generating matting laplacian 189 / 510
# generating matting laplacian 190 / 510
# generating matting laplacian 191 / 510
# generating matting laplacian 192 / 510
# generating matting laplacian 193 / 510
# generating matting laplacian 194 / 510
# generating matting laplacian 195 / 510
# generating matting laplacian 196 / 510
# generating matting laplacian 197 / 510
# generating matting laplacian 198 / 510
# generating matting laplacian 199 / 510
# generating matting laplacian 200 / 510
# generating matting laplacian 201 / 510
# generating matting laplacian 202 / 510
# generating matting laplacian 203 / 510
# generating matting laplacian 204 / 510
# generating matting laplacian 205 / 510
# generating matting laplacian 206 / 510
# generating matting laplacian 207 / 510
# generating matting laplacian 208 / 510
# generating matting laplacian 209 / 510
# generating matting laplacian 210 / 510
# generating matting laplacian 211 / 510
# generating matting laplacian 212 / 510
# generating matting laplacian 213 / 510
# generating matting laplacian 214 / 510
# generating matting laplacian 215 / 510
# generating matting laplacian 216 / 510
# generating matting laplacian 217 / 510
# generating matting laplacian 218 / 510
# generating matting laplacian 219 / 510
# generating matting laplacian 220 / 510
# generating matting laplacian 221 / 510
# generating matting laplacian 222 / 510
# generating matting laplacian 223 / 510
# generating matting laplacian 224 / 510
# generating matting laplacian 225 / 510
# generating matting laplacian 226 / 510
# generating matting laplacian 227 / 510
# generating matting laplacian 228 / 510
# generating matting laplacian 229 / 510
# generating matting laplacian 230 / 510
# generating matting laplacian 231 / 510
# generating matting laplacian 232 / 510
# generating matting laplacian 233 / 510
# generating matting laplacian 234 / 510
# generating matting laplacian 235 / 510
# generating matting laplacian 236 / 510
# generating matting laplacian 237 / 510
# generating matting laplacian 238 / 510
# generating matting laplacian 239 / 510
# generating matting laplacian 240 / 510
# generating matting laplacian 241 / 510
# generating matting laplacian 242 / 510
# generating matting laplacian 243 / 510
# generating matting laplacian 244 / 510
# generating matting laplacian 245 / 510
# generating matting laplacian 246 / 510
# generating matting laplacian 247 / 510
# generating matting laplacian 248 / 510
# generating matting laplacian 249 / 510
# generating matting laplacian 250 / 510
# generating matting laplacian 251 / 510
# generating matting laplacian 252 / 510
# generating matting laplacian 253 / 510
# generating matting laplacian 254 / 510
# generating matting laplacian 255 / 510
# generating matting laplacian 256 / 510
# generating matting laplacian 257 / 510
# generating matting laplacian 258 / 510
# generating matting laplacian 259 / 510
# generating matting laplacian 260 / 510
# generating matting laplacian 261 / 510
# generating matting laplacian 262 / 510
# generating matting laplacian 263 / 510
# generating matting laplacian 264 / 510
# generating matting laplacian 265 / 510
# generating matting laplacian 266 / 510
# generating matting laplacian 267 / 510
# generating matting laplacian 268 / 510
# generating matting laplacian 269 / 510
# generating matting laplacian 270 / 510
# generating matting laplacian 271 / 510
# generating matting laplacian 272 / 510
# generating matting laplacian 273 / 510
# generating matting laplacian 274 / 510
# generating matting laplacian 275 / 510
# generating matting laplacian 276 / 510
# generating matting laplacian 277 / 510
# generating matting laplacian 278 / 510
# generating matting laplacian 279 / 510
# generating matting laplacian 280 / 510
# generating matting laplacian 281 / 510
# generating matting laplacian 282 / 510
# generating matting laplacian 283 / 510
# generating matting laplacian 284 / 510
# generating matting laplacian 285 / 510
# generating matting laplacian 286 / 510
# generating matting laplacian 287 / 510
# generating matting laplacian 288 / 510
# generating matting laplacian 289 / 510
# generating matting laplacian 290 / 510
# generating matting laplacian 291 / 510
# generating matting laplacian 292 / 510
# generating matting laplacian 293 / 510
# generating matting laplacian 294 / 510
# generating matting laplacian 295 / 510
# generating matting laplacian 296 / 510
# generating matting laplacian 297 / 510
# generating matting laplacian 298 / 510
# generating matting laplacian 299 / 510
# generating matting laplacian 300 / 510
# generating matting laplacian 301 / 510
# generating matting laplacian 302 / 510
# generating matting laplacian 303 / 510
# generating matting laplacian 304 / 510
# generating matting laplacian 305 / 510
# generating matting laplacian 306 / 510
# generating matting laplacian 307 / 510
# generating matting laplacian 308 / 510
# generating matting laplacian 309 / 510
# generating matting laplacian 310 / 510
# generating matting laplacian 311 / 510
# generating matting laplacian 312 / 510
# generating matting laplacian 313 / 510
# generating matting laplacian 314 / 510
# generating matting laplacian 315 / 510
# generating matting laplacian 316 / 510
# generating matting laplacian 317 / 510
# generating matting laplacian 318 / 510
# generating matting laplacian 319 / 510
# generating matting laplacian 320 / 510
# generating matting laplacian 321 / 510
# generating matting laplacian 322 / 510
# generating matting laplacian 323 / 510
# generating matting laplacian 324 / 510
# generating matting laplacian 325 / 510
# generating matting laplacian 326 / 510
# generating matting laplacian 327 / 510
# generating matting laplacian 328 / 510
# generating matting laplacian 329 / 510
# generating matting laplacian 330 / 510
# generating matting laplacian 331 / 510
# generating matting laplacian 332 / 510
# generating matting laplacian 333 / 510
# generating matting laplacian 334 / 510
# generating matting laplacian 335 / 510
# generating matting laplacian 336 / 510
# generating matting laplacian 337 / 510
# generating matting laplacian 338 / 510
# generating matting laplacian 339 / 510
# generating matting laplacian 340 / 510
# generating matting laplacian 341 / 510
# generating matting laplacian 342 / 510
# generating matting laplacian 343 / 510
# generating matting laplacian 344 / 510
# generating matting laplacian 345 / 510
# generating matting laplacian 346 / 510
# generating matting laplacian 347 / 510
# generating matting laplacian 348 / 510
# generating matting laplacian 349 / 510
# generating matting laplacian 350 / 510
# generating matting laplacian 351 / 510
# generating matting laplacian 352 / 510
# generating matting laplacian 353 / 510
# generating matting laplacian 354 / 510
# generating matting laplacian 355 / 510
# generating matting laplacian 356 / 510
# generating matting laplacian 357 / 510
# generating matting laplacian 358 / 510
# generating matting laplacian 359 / 510
# generating matting laplacian 360 / 510
# generating matting laplacian 361 / 510
# generating matting laplacian 362 / 510
# generating matting laplacian 363 / 510
# generating matting laplacian 364 / 510
# generating matting laplacian 365 / 510
# generating matting laplacian 366 / 510
# generating matting laplacian 367 / 510
# generating matting laplacian 368 / 510
# generating matting laplacian 369 / 510
# generating matting laplacian 370 / 510
# generating matting laplacian 371 / 510
# generating matting laplacian 372 / 510
# generating matting laplacian 373 / 510
# generating matting laplacian 374 / 510
# generating matting laplacian 375 / 510
# generating matting laplacian 376 / 510
# generating matting laplacian 377 / 510
# generating matting laplacian 378 / 510
# generating matting laplacian 379 / 510
# generating matting laplacian 380 / 510
# generating matting laplacian 381 / 510
# generating matting laplacian 382 / 510
# generating matting laplacian 383 / 510
# generating matting laplacian 384 / 510
# generating matting laplacian 385 / 510
# generating matting laplacian 386 / 510
# generating matting laplacian 387 / 510
# generating matting laplacian 388 / 510
# generating matting laplacian 389 / 510
# generating matting laplacian 390 / 510
# generating matting laplacian 391 / 510
# generating matting laplacian 392 / 510
# generating matting laplacian 393 / 510
# generating matting laplacian 394 / 510
# generating matting laplacian 395 / 510
# generating matting laplacian 396 / 510
# generating matting laplacian 397 / 510
# generating matting laplacian 398 / 510
# generating matting laplacian 399 / 510
# generating matting laplacian 400 / 510
# generating matting laplacian 401 / 510
# generating matting laplacian 402 / 510
# generating matting laplacian 403 / 510
# generating matting laplacian 404 / 510
# generating matting laplacian 405 / 510
# generating matting laplacian 406 / 510
# generating matting laplacian 407 / 510
# generating matting laplacian 408 / 510
# generating matting laplacian 409 / 510
# generating matting laplacian 410 / 510
# generating matting laplacian 411 / 510
# generating matting laplacian 412 / 510
# generating matting laplacian 413 / 510
# generating matting laplacian 414 / 510
# generating matting laplacian 415 / 510
# generating matting laplacian 416 / 510
# generating matting laplacian 417 / 510
# generating matting laplacian 418 / 510
# generating matting laplacian 419 / 510
# generating matting laplacian 420 / 510
# generating matting laplacian 421 / 510
# generating matting laplacian 422 / 510
# generating matting laplacian 423 / 510
# generating matting laplacian 424 / 510
# generating matting laplacian 425 / 510
# generating matting laplacian 426 / 510
# generating matting laplacian 427 / 510
# generating matting laplacian 428 / 510
# generating matting laplacian 429 / 510
# generating matting laplacian 430 / 510
# generating matting laplacian 431 / 510
# generating matting laplacian 432 / 510
# generating matting laplacian 433 / 510
# generating matting laplacian 434 / 510
# generating matting laplacian 435 / 510
# generating matting laplacian 436 / 510
# generating matting laplacian 437 / 510
# generating matting laplacian 438 / 510
# generating matting laplacian 439 / 510
# generating matting laplacian 440 / 510
# generating matting laplacian 441 / 510
# generating matting laplacian 442 / 510
# generating matting laplacian 443 / 510
# generating matting laplacian 444 / 510
# generating matting laplacian 445 / 510
# generating matting laplacian 446 / 510
# generating matting laplacian 447 / 510
# generating matting laplacian 448 / 510
# generating matting laplacian 449 / 510
# generating matting laplacian 450 / 510
# generating matting laplacian 451 / 510
# generating matting laplacian 452 / 510
# generating matting laplacian 453 / 510
# generating matting laplacian 454 / 510
# generating matting laplacian 455 / 510
# generating matting laplacian 456 / 510
# generating matting laplacian 457 / 510
# generating matting laplacian 458 / 510
# generating matting laplacian 459 / 510
# generating matting laplacian 460 / 510
# generating matting laplacian 461 / 510
# generating matting laplacian 462 / 510
# generating matting laplacian 463 / 510
# generating matting laplacian 464 / 510
# generating matting laplacian 465 / 510
# generating matting laplacian 466 / 510
# generating matting laplacian 467 / 510
# generating matting laplacian 468 / 510
# generating matting laplacian 469 / 510
# generating matting laplacian 470 / 510
# generating matting laplacian 471 / 510
# generating matting laplacian 472 / 510
# generating matting laplacian 473 / 510
# generating matting laplacian 474 / 510
# generating matting laplacian 475 / 510
# generating matting laplacian 476 / 510
# generating matting laplacian 477 / 510
# generating matting laplacian 478 / 510
# generating matting laplacian 479 / 510
# generating matting laplacian 480 / 510
# generating matting laplacian 481 / 510
# generating matting laplacian 482 / 510
# generating matting laplacian 483 / 510
# generating matting laplacian 484 / 510
# generating matting laplacian 485 / 510
# generating matting laplacian 486 / 510
# generating matting laplacian 487 / 510
# generating matting laplacian 488 / 510
# generating matting laplacian 489 / 510
# generating matting laplacian 490 / 510
# generating matting laplacian 491 / 510
# generating matting laplacian 492 / 510
# generating matting laplacian 493 / 510
# generating matting laplacian 494 / 510
# generating matting laplacian 495 / 510
# generating matting laplacian 496 / 510
# generating matting laplacian 497 / 510
# generating matting laplacian 498 / 510
# generating matting laplacian 499 / 510
# generating matting laplacian 500 / 510
# generating matting laplacian 501 / 510
# generating matting laplacian 502 / 510
# generating matting laplacian 503 / 510
# generating matting laplacian 504 / 510
# generating matting laplacian 505 / 510
# generating matting laplacian 506 / 510
# generating matting laplacian 507 / 510
# generating matting laplacian 508 / 510
# generating matting laplacian 509 / 510
# generating matting laplacian 510 / 510
# solving linear system...

# %%
from pymatting import cutout

image_path  = "FBAMATING_PunyaGambar/every-type-of-bike-c052991.jpg"
trimap_path = "FBAMATING_PunyaGambar/trimaps/every-type-of-bike-c052991.png"
alpha_path  = "bikebike.png"
cutout_path = "bikebike_cutout.png"

cutout(
   # input image path
   image_path,
   # input trimap path
   trimap_path,
   # output cutout path
   "bikebike_cutout.png")

# %%
from pymatting import *
import numpy as np

scale = 1.0

image = load_image(image_path, "RGB", scale, "box")
trimap = load_image(trimap_path, "GRAY", scale, "nearest")

# estimate alpha from image and trimap
alpha = estimate_alpha_cf(image, trimap)

# make gray background
background = np.zeros(image.shape)
background[:, :] = [0.5, 0.5, 0.5]

# estimate foreground from image and alpha
foreground = estimate_foreground_ml(image, alpha)

# blend foreground with background and alpha, less color bleeding
new_image = blend(foreground, background, alpha)

# save results in a grid
images = [image, trimap, alpha, new_image]
grid = make_grid(images)
save_image("bikebike_grid.png", grid)

# save cutout
cutout = stack_images(foreground, alpha)
save_image("bikebike_cutout2.png", cutout)

# just blending the image with alpha results in color bleeding
color_bleeding = blend(image, background, alpha)
grid = make_grid([color_bleeding, new_image])
save_image("bikebike.png", grid)

# %%
from pymatting import *
import numpy as np
import scipy.sparse

scale = 1.0

image = load_image(image_path, size=scale, resample="box")
trimap = load_image(trimap_path, mode="GRAY", size=scale, resample="nearest")

# height and width of trimap
h, w = trimap.shape[:2]

# calculate laplacian matrix
L = cf_laplacian(image)

# decompose trimap
is_fg, is_bg, is_known, is_unknown = trimap_split(trimap)

# constraint weight
lambda_value = 100.0

# build constraint pixel selection matrix
c = lambda_value * is_known
C = scipy.sparse.diags(c)

# build constraint value vector
b = lambda_value * is_fg

# build linear system
A = L + C

# build ichol preconditioner for faster convergence
A = A.tocsr()
A.sum_duplicates()
M = ichol(A)

# solve linear system with conjugate gradient descent
x = cg(A, b, M=M)

# clip and reshape result vector
alpha = np.clip(x, 0.0, 1.0).reshape(h, w)

save_image("lemur_alpha.png", alpha)

# %%
import cv2

alpha_image = 'lemur_alpha.png'
real_image = image_path

# %%
# import PIL module
from PIL import Image
# Load the images
myBackgroundImage = Image.open("FBAMATING_PunyaGambar/bg2.jpg")
myForegroundImage = Image.open("bikebike_cutout.png")
# Create a new image with the same size as the background image
myMerged_image = Image.new("RGBA", myBackgroundImage.size)
# Paste the background image onto the new image
myMerged_image.paste(myBackgroundImage, (0, 0))
# Create a mask from the alpha channel of the foreground image
_, _, _, mask = myForegroundImage.split()
# Paste the foreground image onto the new image with the mask
myMerged_image.paste(myForegroundImage, (0, 0), mask)
# Saving the merged image to a file
myMerged_image.save("yourmergedbike.jpg", 'jpeg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\JpegImagePlugin.py:650, in _save(im, fp, filename)
#     649 try:
# --> 650     rawmode = RAWMODE[im.mode]
#     651 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 15
#      13 myMerged_image.paste(myForegroundImage, (0, 0), mask)
#      14 # Saving the merged image to a file
# ---> 15 myMerged_image.save("yourmerged.jpg", 'jpeg')
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:2439, in Image.save(self, fp, format, **params)
#    2436         fp = builtins.open(filename, "w+b")
#    2438 try:
# -> 2439     save_handler(self, fp, filename)
#    2440 except Exception:
#    2441     if open_fp:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\JpegImagePlugin.py:653, in _save(im, fp, filename)
#     651 except KeyError as e:
#     652     msg = f"cannot write mode {im.mode} as JPEG"
# --> 653     raise OSError(msg) from e
#     655 info = im.encoderinfo
#     657 dpi = [round(x) for x in info.get("dpi", (0, 0))]
#
# OSError: cannot write mode RGBA as JPEG

# %%
from PIL import Image as img

# Open images
cat_image = img.open("bikebike_cutout.png")
background = img.open("FBAMATING_PunyaGambar/bg2.jpg")

width, height = cat_image.size
background = background.resize((width * 2, height * 2), img.LANCZOS)

paste_position = (background.width // 2 - width // 2, background.height // 2 - height // 2)

background.paste(cat_image, paste_position, mask=cat_image)

background.show()
