# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imgs = []
img_path = ['UTS_FILE/Nomer3/Bengkok1.jpg', 'UTS_FILE/Nomer3/Bengkok2.jpg', 'UTS_FILE/Nomer3/Bengkok3.jpg']


for i in range(len(img_path)):
    imgs.append(cv2.imread(img_path[i]))
    # imgs[i]=cv2.resize(imgs[i],(0,0),fx=0.4,fy=0.4) 


stitching = cv2.Stitcher.create()
(dummy,output)=stitching.stitch(imgs) 

output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)

if dummy != cv2.STITCHER_OK:
    print("Not success")
else:
     print("Success")

plt.imshow(output)
print(output.shape)
# Out:
# Success
# (862, 1764, 3)

# %%
imgs2 = []
img_path2 = ['UTS_FILE/Nomer3/Rata1.jpg', 'UTS_FILE/Nomer3/Rata2.jpg', 'UTS_FILE/Nomer3/Rata3.jpg']


for i in range(len(img_path2)):
    imgs2.append(cv2.imread(img_path2[i]))
    # tes = cv2.imread(img_path[i])
    # plt.imshow(tes)
    imgs2[i]=cv2.resize(imgs2[i],(0,0),fx=0.4,fy=0.4) 


stitching2 = cv2.Stitcher.create()
(dummy2,output2)=stitching.stitch(imgs2) 

output2 = cv2.cvtColor(output2, cv2.COLOR_BGR2RGB)

if dummy2 != cv2.STITCHER_OK:
    print("Not success")
else:
    print("Success")
     
    plt.imshow(output2)
    print(output2.shape)
# Out:
# Success
# (350, 631, 3)
